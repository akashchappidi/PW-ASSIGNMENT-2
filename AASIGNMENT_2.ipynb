# %% [markdown]
# ASSIGNMENT-2
#
#
#
# Q-1 What are data structures, and why are they important ?
#
# ->Data structures are organized ways to store and manage data efficiently. They are crucial in Python as they determine how data is accessed, manipulated, and used in algorithms. Common examples include lists, dictionaries, sets, and trees, each with its own strengths for different tasks.
#
# Q-2 Explain the difference between mutable and immutable data  types with examples
#
# -->Mutable Data Types:
#
# Values can be changed after creation.
# Examples: Lists, dictionaries, sets.
#
# Immutable Data Types:
#
# Values cannot be changed after creation.
# Examples: Integers, floats, strings, tuples.
#
# Q-3) What are the main differences between lists and tuples in PythON?
# -->Mutability:
#
# Lists: Mutable, meaning their elements can be changed, added, or removed after creation.
#
# Tuples: Immutable, meaning their elements cannot be changed once created.
# Syntax:
#
# Lists: Enclosed in square brackets [].
# Tuples: Enclosed in parentheses ().
#
# Q-4) Describe how dictionaries store data.
#
# --> Dictionaries in Python store data in key-value pairs. This means that each piece of data is associated with a unique identifier called a key. To access a specific value, you use its corresponding key
#
# Q-5)  Why might you use a set instead of a list in Python
#
# -->Sets guarantee uniqueness of elements, eliminating the need for duplicate removal.
# Membership checks in sets are significantly faster than in lists due to their underlying hash-based implementation.
# Sets efficiently support mathematical set operations like union, intersection, and difference, making them well-suited for tasks involving set logic.
#
# Q-6) What is a string in Python, and how is it different from a list
#
# -->Strings are immutable sequences of characters, representing text data.
# Lists are mutable collections of arbitrary objects, including strings, numbers, and other data types.
# Key difference: Strings cannot be modified after creation, while lists allow for dynamic changes like adding, removing, or modifying elements.
#
# Q-7) How do tuples ensure data integrity in Python
#
# -->tuples are immutable, meaning their contents cannot be changed after creation.
# This immutability prevents accidental modifications, ensuring data consistency and reliability, especially when dealing with sensitive or critical information.
#
# Q-8) What is a hash table, and how does it relate to dictionaries in Python
#
# -->A hash table is a data structure that uses a hash function to map keys to specific locations within an array, enabling fast data access. Python dictionaries are implemented using hash tables, allowing for efficient storage and retrieval of key-value pairs.
#
# Q-9) Can lists contain different data types in Python
# -->Yes, lists in Python are incredibly versatile. They can hold elements of different data types within the same list. This allows for flexible data representation and manipulation.
#
# Q-10) Explain why strings are immutable in Python
# --> Efficiency: Immutability allows for string interning, where common strings are stored only once in memory, saving space and improving performance.
# Security: Immutability helps prevent accidental or malicious modifications to string data, enhancing the security of applications.
#
# Q-11) What advantages do dictionaries offer over lists for certain tasks ?
# -->Fast lookups: You need to quickly access data based on unique identifiers (keys)
# Data organization: You want to organize data into key-value pairs, providing a more structured and meaningful way to represent relationships.
#
# Q-12) Describe a scenario where using a tuple would be preferable
#
# -->You would prefer a tuple over a list when you need to ensure that a collection of data remains constant and cannot be accidentally modified, such as when storing configuration settings or representing immutable coordinates.
#
# Q-13) How do sets handle duplicate values in Python
# --> Python, sets automatically remove duplicate values, ensuring that each element within the set is unique.
#
# Q-14)  How does the “in” keyword work differently for lists and dictionaries
# --> Lists: The in keyword checks if a value exists within the sequence of elements in the list.
# Dictionaries: The in keyword checks if a given key exists within the dictionary.
#
# Q-15)Can you modify the elements of a tuple? Explain why or why not
# -->No, you cannot modify the elements of a tuple. Tuples are immutable, meaning their values cannot be changed after they are created. This ensures data integrity and prevents accidental 1  alterations.
#
# Q-16)What is a nested dictionary, and give an example of its use case
#
# -->A nested dictionary is a dictionary where the values are themselves dictionaries, enabling the representation of hierarchical data.
#
# Q-17) Describe the time complexity of accessing elements in a dictionary
# -->The time complexity of accessing elements in a dictionary is O(1), meaning it typically takes constant time, regardless of the dictionary's size.
#
# Q-18) In what situations are lists preferred over dictionaries
# -->Ordered sequences: When maintaining the order of elements is crucial, lists are preferred.
# Flexible modifications: When frequent additions, removals, and modifications are needed, lists provide more flexibility than dictionaries.
#
# Q-19) Why are dictionaries considered unordered, and how does that affect data retrieval
# -->Dictionaries in Python are considered unordered because they don't maintain a specific sequence of their key-value pairs. While they preserve insertion order in recent Python versions, it's not guaranteed. This doesn't affect key-based lookups, but it can impact operations that rely on the order of items, such as iteration.
#
# Q-20) Explain the difference between a list and a dictionary in terms of data retrieval.
#
# -->Lists: Retrieve elements based on their position (index), which can be less efficient for large lists.
# Dictionaries: Retrieve values based on their unique keys, providing extremely fast lookups in constant time (O(1)

# %%
#PRACTICAL QUESTION

#1) WRITE A CODE TO CREATE A STRING WITH YOUR NAME AND PRINT IT.
name=input("Enter the name")
print(name)

#2 WRITE A CODE TO FIND THE LENGTH OF THE STRING "HELLO WORLD"
print(len("HELLO WORLD"))

#3  Write a code to slice the first 3 characters from the string "Python Programming"
name="Python Programming"
print(name[0:18:3])

#4 Write a code to convert the string "hello" to uppercase
name="hello"
print(name.upper())

#5 Write a code to replace the word "apple" with "orange" in the string "I like apple"
s="i like apple"
print(s.replace("apple","orange"))

#6  Write a code to create a list with numbers 1 to 5 and print it
for i in range(1,5):
  print(i)

#7  Write a code to append the number 10 to the list [1, 2, 3, 4]
l=[1,2,3,4]
1.append(10)
print(l)

#8 Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]E
l=[1,2,3,4]
1.remove(3)
print(l)

#9 Write a code to access the second element in the list ['a', 'b', 'c', 'd']
l=['a', 'b', 'c', 'd']
print(l[1])

#10 " Write a code to reverse the list [10, 20, 30, 40, 50]
l= [10, 20, 30, 40, 50]
print(l[::-1])

#11 Write a code to create a tuple with the elements 10, 20, 30 and print it
l= (10, 20, 30)

print(l)

#12  Write a code to access the first element of the tuple ('apple', 'banana', 'cherry')
l=('apple', 'banana', 'cherry')
print(l[0])

#13  Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
l=(1, 2, 3, 2, 4, 2)
print(l.count(2))
print(l)

#14  Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
t=('dog', 'cat', 'rabbit')
for i in range(len(t)):
  if( t[i] == 'cat'):
    print(i)

#15 Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
tuple=('apple', 'orange', 'banana')
print('banana' in tuple)

#16  Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.

set={1,2,3,4,5}
print(set)

#17 . Write a code to add the element 6 to the set {1, 2, 3, 4}.
n={1, 2, 3, 4}
n.add(6)
print(n)

#18 Write a code to create a tuple with the elements 10, 20, 30 and print it
l= (10, 20, 30)
print(l)

#19  Write a code to access the first element of the tuple ('apple', 'banana', 'cherry')
l=('apple', 'banana', 'cherry')
print(l[0])

#20  Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
l=(1, 2, 3, 2, 4, 2)
print(l.count(2))
print(l)

#21 Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
t=('dog', 'cat', 'rabbit')
for i in range(len(t)):
  if( t[i] == 'cat'):
    print(i)

#22 Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
tuple=('apple', 'orange', 'banana')
print('banana' in tuple)

#23  Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.

set={1,2,3,4,5}
print(set)

#24 Write a code to add the element 6 to the set {1, 2, 3, 4}.
n={1, 2, 3, 4}
n.add(6)
print(n)
